# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("weather_data.csv")
df.head() #....this fucntion show us to frist five rows entry of dataframes....head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# how to analyize data...frame

# %% [markdown]
# ##### this function shows us to how many rows and columns we have....shape()

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# ##### ...this function show columns names of dataframe...

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# ##### this attribute provide names index of dataframe...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# ##### #its showss the datatyoes of each columns

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# ##### #this function show us uniquu values in columns....and this function only apply on dataframe columns...

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ##### its show us to unique value in each columns

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# ##### .count() function show us no null value in each colums...it can be appply on single colunms as well as whole dataframe

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ##### value_count() this function is only apply on only single columsns of dataframe

# %%
df["Visibility_km"].value_counts().head()
# Out:
# 25.0    3324
# 48.3    2014
# 24.1    1921
# 19.3     281
# 16.1     224
# Name: Visibility_km, dtype: int64

# %% [markdown]
# ##### provide the basic information of dataframe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ##### Q1 find all unqiue values wind speed data...

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique() #this is ans of this question
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# ##### Q2..find the exacat clear weather is exactly clear

# %%
df.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# were doing filtering() on columns..

# %%
df[df.Weather == 'Clear'].head(3)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear

# %%
df[df.Temp_C == -9.0].head(2) #this is'nt part of this question...this is for option
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 48    1/3/2012 0:00    -9.0             -16.0         57               28
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa       Weather
# 48            25.0     100.35  Snow Showers
# 117           25.0     100.83         Clear

# %%
# were using groupby(funtion)

# %%
df.groupby('Weather').get_group('Clear').head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
df.groupby('Weather').get_group('Snow Showers').head() #this is for option..
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5         57               22
# 44  1/2/2012 20:00    -5.6             -13.4         54               24
# 45  1/2/2012 21:00    -5.8             -12.8         58               26
# 47  1/2/2012 23:00    -7.4             -14.1         59               17
# 48   1/3/2012 0:00    -9.0             -16.0         57               28
#
#     Visibility_km  Press_kPa       Weather
# 41           25.0      99.66  Snow Showers
# 44           25.0     100.07  Snow Showers
# 45           25.0     100.15  Snow Showers
# 47           19.3     100.27  Snow Showers
# 48           25.0     100.35  Snow Showers

# %% [markdown]
# ##### find the  num of times when the wind speed was excatly 4km/hrs

# %%
df[df['Wind Speed_km/h']==4].head() #....this is the ans of this question..
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
# 146  1/7/2012 2:00    -8.1             -11.1         79                4
#
#      Visibility_km  Press_kPa Weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %%
df[df['Temp_C']== -1.8].tail(3)   #...this is for options
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8172  12/6/2012 12:00    -1.8              -9.4         56                6
# 8187   12/7/2012 3:00    -1.8              -5.3         77                9
# 8503  12/20/2012 7:00    -1.8              -4.9         79               20
#
#       Visibility_km  Press_kPa       Weather
# 8172           48.3     102.37  Mainly Clear
# 8187           25.0     101.46  Mainly Clear
# 8503           25.0     101.88        Cloudy

# %% [markdown]
# ##### Q3` find the null values in the dataframe

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date/Time           False
# Temp_C              False
# Dew Point Temp_C    False
# Rel Hum_%           False
# Wind Speed_km/h     False
# Visibility_km       False
# Press_kPa           False
# Weather             False
# dtype: bool

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ##### Q4 Rename the dataframe columns names 'weather' to  'weather conditon'..

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
# were using this function to change columns names

# %%
df.rename(columns={'Weather':'Weather condition'}).head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
df.rename(columns = {'Visibility_km' :'Visibility'},inplace=True)  # this is for option

# %%
df.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility  Press_kPa               Weather
# 0         8.0     101.24                   Fog
# 1         8.0     101.24                   Fog
# 2         4.0     101.26  Freezing Drizzle,Fog

# %% [markdown]
# ##### Q5 what is mean of visibility of columns

# %%
df.head(1)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
#
#    Visibility  Press_kPa Weather
# 0         8.0     101.24     Fog

# %%
df['Visibility'].mean()
# Out:
# 27.664446721311478

# %%
df.Visibility.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ##### Q5..what is this std devision of this 'Press_kPa'...

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
df['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# ##### q6 what is the  variance of relative humidity in this data

# %%
df.head(1)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
#
#    Visibility  Press_kPa Weather
# 0         8.0     101.24     Fog

# %%
df['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# ##### Q7 find instances of the when snow was %recorded

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility  Press_kPa Weather
# 0         8.0     101.24     Fog
# 1         8.0     101.24     Fog

# %%
df['Weather'].value_counts().head()
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Name: Weather, dtype: int64

# %%
df[df['Weather']=='Snow'].head(4)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   1/3/2012 7:00   -14.0             -19.5         63               19
# 84  1/4/2012 12:00   -13.7             -21.7         51               11
# 86  1/4/2012 14:00   -11.3             -19.0         53                7
# 87  1/4/2012 15:00   -10.2             -16.3         61               11
#
#     Visibility  Press_kPa Weather
# 55        25.0     100.95    Snow
# 84        24.1     101.25    Snow
# 86        19.3     100.97    Snow
# 87         9.7     100.89    Snow

# %%
df[df['Weather'].str.contains('Snow')].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5         57               22
# 44  1/2/2012 20:00    -5.6             -13.4         54               24
# 45  1/2/2012 21:00    -5.8             -12.8         58               26
# 47  1/2/2012 23:00    -7.4             -14.1         59               17
# 48   1/3/2012 0:00    -9.0             -16.0         57               28
#
#     Visibility  Press_kPa       Weather
# 41        25.0      99.66  Snow Showers
# 44        25.0     100.07  Snow Showers
# 45        25.0     100.15  Snow Showers
# 47        19.3     100.27  Snow Showers
# 48        25.0     100.35  Snow Showers

# %% [markdown]
# ##### q7 find all intneceses when wind speed  is abobe 24 and visibility 25.

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility  Press_kPa Weather
# 0         8.0     101.24     Fog
# 1         8.0     101.24     Fog

# %%
df[df['Wind Speed_km/h']>24].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
# 24   1/2/2012 0:00     5.2               1.5         77               35
# 25   1/2/2012 1:00     4.6               0.0         72               39
# 26   1/2/2012 2:00     3.9              -0.9         71               32
# 27   1/2/2012 3:00     3.7              -1.5         69               33
#
#     Visibility  Press_kPa        Weather
# 23        25.0      99.31         Cloudy
# 24        25.0      99.26   Rain Showers
# 25        25.0      99.26         Cloudy
# 26        25.0      99.26  Mostly Cloudy
# 27        25.0      99.30  Mostly Cloudy

# %%
df[df['Wind Speed_km/h']<25].tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
#
#       Visibility  Press_kPa Weather
# 8775         9.7     100.47    Snow
# 8776        12.9     100.40    Snow
# 8777         9.7     100.30    Snow
# 8778         9.7     100.19    Snow
# 8780         9.7     100.03    Snow

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility']==25)].tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
#       Visibility  Press_kPa        Weather
# 8705        25.0     101.34   Mainly Clear
# 8753        25.0     101.26   Mainly Clear
# 8755        25.0     101.47   Mainly Clear
# 8759        25.0     101.52  Mostly Cloudy
# 8760        25.0     101.51         Cloudy

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility']==25)].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
# 24   1/2/2012 0:00     5.2               1.5         77               35
# 25   1/2/2012 1:00     4.6               0.0         72               39
# 26   1/2/2012 2:00     3.9              -0.9         71               32
# 27   1/2/2012 3:00     3.7              -1.5         69               33
#
#     Visibility  Press_kPa        Weather
# 23        25.0      99.31         Cloudy
# 24        25.0      99.26   Rain Showers
# 25        25.0      99.26         Cloudy
# 26        25.0      99.26  Mostly Cloudy
# 27        25.0      99.30  Mostly Cloudy

# %% [markdown]
# ##### what is the mean value of each columns against 'weather condition'?

# %%
df.groupby('Weather').mean().head()
# Out:
# C:\Users\GAURAV SHELAR\AppData\Local\Temp\ipykernel_17352\1765250707.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Weather').mean().head()
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility   Press_kPa
# Weather
# Clear                          10.557315   30.153243  101.587443
# Cloudy                         16.127315   26.625752  100.911441
# ...

# %%
df.groupby(['Weather']).mean().tail()
# Out:
# C:\Users\GAURAV SHELAR\AppData\Local\Temp\ipykernel_17352\3308731496.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Weather']).mean().tail()
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Thunderstorms,Moderate Rain Showers,Fog  19.600000         18.500000
# Thunderstorms,Rain                       20.433333         18.533333
# Thunderstorms,Rain Showers               20.037500         17.618750
# Thunderstorms,Rain Showers,Fog           21.600000         18.700000
# Thunderstorms,Rain,Fog                   20.600000         18.600000
#
#                                          Rel Hum_%  Wind Speed_km/h  \
# Weather
# Thunderstorms,Moderate Rain Showers,Fog     93.000        15.000000
# ...

# %% [markdown]
# ##### what is max and min vlaue of each columns agianst weather conditon....

# %%
df.tail(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility  Press_kPa Weather
# 8782         9.7      99.91    Snow
# 8783        11.3      99.89    Snow

# %%
df.groupby('Weather').min()
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility  Press_kPa Weather
# 0         8.0     101.24     Fog
# 1         8.0     101.24     Fog

# %%
df.groupby('Weather').max()
df.tail(3)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility  Press_kPa Weather
# 8781         4.8      99.95    Snow
# 8782         9.7      99.91    Snow
# 8783        11.3      99.89    Snow

# %% [markdown]
# ##### show all the records weather condition is fog...

# %%
df[df['Weather']=="Fog"].tail(3)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility  Press_kPa Weather
# 8718         9.7     101.25     Fog
# 8719         8.0     101.22     Fog
# 8722         6.4     101.15     Fog

# %%
# find all intances weather is clear visibility more that 40...

# %%
df[df["Weather"]=='Clear'].head(3)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
#
#      Visibility  Press_kPa Weather
# 67         25.0     101.74   Clear
# 114        25.0     100.71   Clear
# 115        25.0     100.80   Clear

# %%
df[(df['Weather']=='Clear') | (df['Visibility']>40)].head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
#
#      Visibility  Press_kPa       Weather
# 67         25.0     101.74         Clear
# 106        48.3     100.45  Mainly Clear
# 107        48.3     100.41  Mainly Clear
# 108        48.3     100.38  Mainly Clear
# 109        48.3     100.40  Mainly Clear

# %%
df[(df['Weather']=="Clear") & (df['Rel Hum_%']>50) | (df['Visibility']>40)].head(10)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
# 110  1/5/2012 14:00    -5.1             -10.7         65               22
# 111  1/5/2012 15:00    -4.3             -12.0         55               26
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility  Press_kPa       Weather
# 106        48.3     100.45  Mainly Clear
# 107        48.3     100.41  Mainly Clear
# ...
